# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
# model = YOLO('yolov8s.pt')
model = YOLO('yolov8s.pt')


# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='/home/dfundo/workspace/VIR_projekt/labeled_images_rotated_resized/data.yaml', cfg='/home/dfundo/workspace/VIR_projekt/args.yaml')

# results = model.train(data='/home/dfundo/workspace/VIR_projekt/labeled_images_rotated_resized/data.yaml', epochs=400, imgsz=800,batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.0.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
import os
from PIL import Image
from ultralytics import YOLO

# Specify the folder path where your images are located
folder_path = "/home/dfundo/workspace/VIR_projekt/my_images"
folder_path = "/home/dfundo/workspace/VIR_projekt/labeled_images_rotated_resized/valid"
# folder_path = "/home/dfundo/workspace/VIR_projekt/dataset/train/images"

# model =YOLO('/home/dfundo/workspace/VIR_projekt/runs/detect/train26/weights/best.pt')
# model =YOLO('/home/dfundo/workspace/VIR_projekt/runs/detect/train27/weights/best.pt')
# model =YOLO('/home/dfundo/workspace/VIR_projekt/runs/detect/train276/weights/best.pt')
model =YOLO('/home/dfundo/workspace/VIR_projekt/runs/detect/mold18/weights/best.pt')

# Ensure the folder path is valid
if os.path.exists(folder_path):
    # List all files in the folder
    files = os.listdir(folder_path)
    
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif')):
            # Load the image using Pillow
            image = Image.open(os.path.join(folder_path, file))
            results = model(image,cfg='/home/dfundo/workspace/VIR_projekt/args.yaml',save=True,conf=0.40)  # generator of Results objects
# Out:
# 0: 480x800 7 bread_molds, 125.1ms
# Speed: 1.6ms preprocess, 125.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict35
#
# 0: 480x800 2 bread_molds, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict35
#
# 0: 480x800 2 bread_molds, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict35
#
# 0: 480x800 4 bread_molds, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict35
#
# 0: 480x800 5 bread_molds, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict35
#
# 0: 480x800 1 bread_mold, 10.2ms
# ...
